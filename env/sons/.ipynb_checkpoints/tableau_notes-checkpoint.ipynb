# %%
import pandas
import os

# %%
df = pandas.read_csv('notes.csv')

df
# Out:
#         A       A#         B           C          C#           D          D#  \
# 0    55.0    58.27    61.735    65.40625    69.29625    73.41625    77.78125
# 1   110.0   116.54   123.470   130.81250   138.59250   146.83250   155.56250
# 2   220.0   233.08   246.940   261.62500   277.18500   293.66500   311.12500
# 3   440.0   466.16   493.880   523.25000   554.37000   587.33000   622.25000
# 4   880.0   932.32   987.760  1046.50000  1108.74000  1174.66000  1244.50000
# 5  1760.0  1864.64  1975.520  2093.00000  2217.48000  2349.32000  2489.00000
# 6  3520.0  3729.28  3951.040  4186.00000  4434.96000  4698.64000  4978.00000
# 7  7040.0  7458.56  7902.080  8372.00000  8869.92000  9397.28000  9956.00000
#
#             E           F           F#            G           G#
# 0     82.4075     87.3075     92.49875     97.99875    103.82625
# 1    164.8150    174.6150    184.99750    195.99750    207.65250
# 2    329.6300    349.2300    369.99500    391.99500    415.30500
# ...

# %%
liste = []

# df.iloc[4, 1] - df.iloc[4, 0]

j = 1
l = 3
for i in range(df.shape[1]):
    if i < (df.shape[1] - 1):
#         print(df.iloc[l, j] - df.iloc[l, i])
        print(df.iloc[l, i])
        j +=1
        print(j)
# Out:
# 440.0
# 2
# 466.16
# 3
# 493.88
# 4
# 523.25
# 5
# 554.37
# 6
# 587.33
# 7
# 622.25
# 8
# 659.26
# 9
# 698.46
# 10
# 739.99
# 11
# 783.99
# 12

# %%
415.30500 - 391.99500
# Out:
# 23.310000000000002

# %%
369.99500 - 391.99500
# Out:
# -22.0
